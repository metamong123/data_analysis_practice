# %%
# 데이터 타입 data type

# %%
# 변수 variables

# %%
fish = '고등어'

# %%
# = 의 오른쪽을 =의 왼쪽에 저장하라.

# %%
fish
# Out:
# '고등어'

# %%
price
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 price
#
# NameError: name 'price' is not defined

# %%
price = 3000

# %%
price
# Out:
# 3000

# %%
price*3
# Out:
# 9000

# %%
hello = 'hello'

# %%
hello
# Out:
# 'hello'

# %%
price = 3000

# %% [raw]
# price

# %%
price = 4000

# %%
price
# Out:
# 4000

# %%
price*3
# Out:
# 12000

# %%
temperature = 183.5

# %%
population = 1_000_000_000

# %%
population
# Out:
# 1000000000

# %%
0.00006201
# Out:
# 6.201e-05

# %%
efficiency = 6.201e-5

# %%
efficiency
# Out:
# 6.201e-05

# %%
# 데이터의 가공

## 숫자데이터 가공
## 문자열데이터 가공

# %%
500 + 300
# Out:
# 800

# %%
500 * 3
# Out:
# 1500

# %%
500 / 3
# Out:
# 166.66666666666666

# %%
500 // 3
# Out:
# 166

# %%
500 % 3
# Out:
# 2

# %%
50**3
# Out:
# 125000

# %%
price
# Out:
# 4000

# %%
price - 500
# Out:
# 3500

# %%
(price - 500)*3
# Out:
# 10500

# %%
price*3 - 500
# Out:
# 11500

# %%
price = price - 500

# %%
price
# Out:
# 3500

# %%
data1 = 5

# %%
data2 = 3.5

# %%
data3 = "홍길동"

# %%
type(data1)
# Out:
# int

# %%
type(data2)
# Out:
# float

# %%
type(data3)
# Out:
# str

# %%
data4 = '50'

# %%
data4*4
# Out:
# '50505050'

# %%
type(data4)
# Out:
# str

# %%
int(data4)
# Out:
# 50

# %%
data4 = int(data4)

# %%
data4
# Out:
# 50

# %%
data4*4
# Out:
# 200

# %%
float(data4)
# Out:
# 50.0

# %%
str(data4)
# Out:
# '50'

# %%
# 문자열 데이터

# %%
sentence = """동해물과 백두산이 마르고 닳도록
하느님이 보우하사 우리나라 만세
무궁화 삼천리 화려강산
대한사람 대한으로 길이 보전하세"""

# %%
sentence
# Out:
# '동해물과 백두산이 마르고 닳도록\n하느님이 보우하사 우리나라 만세\n무궁화 삼천리 화려강산\n대한사람 대한으로 길이 보전하세'

# %%
print(sentence)
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려강산
# 대한사람 대한으로 길이 보전하세

# %%
text = 'PYTHON'

# %%
text[0]
# Out:
# 'P'

# %%
text[2]
# Out:
# 'T'

# %%
text[-1]
# Out:
# 'N'

# %%
text[0:2+1]
# Out:
# 'PYT'

# %%
text[:3]
# Out:
# 'PYT'

# %%
text[2:]
# Out:
# 'THON'

# %%
text[-3:]
# Out:
# 'HON'

# %%
text[::2]
# Out:
# 'PTO'

# %%
text[::-1]
# Out:
# 'NOHTYP'

# %%
first_name = 'Smart'
last_name = 'Factory'

# %%
first_name + last_name
# Out:
# 'SmartFactory'

# %%
first_name + ' ' + last_name
# Out:
# 'Smart Factory'

# %%
separator = '*'

# %%
separator * 30
# Out:
# '******************************'

# %%
text.upper()
# Out:
# 'PYTHON'

# %%
text.lower()
# Out:
# 'python'

# %%
text.capitalize()
# Out:
# 'Python'

# %%
text.title()
# Out:
# 'Python'

# %%
email = '  hello@gmail.com  '

# %%
email2 = 'hello@gmail.com'

# %%
email == email2
# Out:
# False

# %%
email.strip()
# Out:
# 'hello@gmail.com'

# %%
email.rstrip()
# Out:
# '  hello@gmail.com'

# %%
text = 'Smart Factory Production Line'

# %%
# 글자가 들어있는 위치를 찾는 방법
text.find('factory')
# Out:
# -1

# %%
text.lower().find('factory')
# Out:
# 6

# %%
text.count('o')
# Out:
# 3

# %%
file_name = 'hello.hwp'

# %%
file_name.startswith('he')
# Out:
# True

# %%
file_name.endswith('hwp')
# Out:
# True

# %%
text.replace('Factory', 'Cars')
# Out:
# 'Smart Cars Production Line'

# %%
text = 'apple apple apple'

# %%
text.replace('apple', 'banana', 1)
# Out:
# 'banana apple apple'

# %%
text.replace('apple', 'banana', 2)
# Out:
# 'banana banana apple'

# %%
# 문자열 분리 => split

# %%
text = "apple,banana,cherry"

# %%
text.split(',')
# Out:
# ['apple', 'banana', 'cherry']

# %%
text = "apple, banana, cherry"

# %%
text.split(', ')
# Out:
# ['apple', 'banana', 'cherry']

# %%
text = "apple, banana,cherry, orange"

# %%
text.replace(' ', '').split(',')
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
fruits = ['apple', 'banana', 'cherry']

# %%
' '.join(fruits)
# Out:
# 'apple banana cherry'

# %%
"12345".isdigit()
# Out:
# True

# %%
"123.45".isdigit()
# Out:
# False

# %%
"Hello".isalpha()
# Out:
# True

# %%
"Hello3".isalpha()
# Out:
# False

# %%
"Hello123".isalnum()
# Out:
# True

# %%
"    ".isspace()
# Out:
# True

# %%
name = "CNC Machine"
temperature = 185.5

# %%
"Machine : %s, Temperature : %.1f"%(name, temperature)
# Out:
# 'Machine : CNC Machine, Temperature : 185.5'

# %%
"Machine : {}, Temperature : {}".format(name, temperature)
# Out:
# 'Machine : CNC Machine, Temperature : 185.5'

# %%
f"Machine : {name}, Temperature : {temperature}"
# Out:
# 'Machine : CNC Machine, Temperature : 185.5'

# %%
is_running = True

# %%
is_defective = False
