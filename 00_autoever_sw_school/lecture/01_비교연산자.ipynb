# %%
5 == 5
# Out:
# True

# %%
5 > 3
# Out:
# True

# %%
5 >= 3
# Out:
# True

# %%
temp = 185.5
target = 180.0

# %%
temp > target
# Out:
# True

# %%
data1 = "apple"
data2 = "banana"

# %%
data1 == 'apple'
# Out:
# True

# %%
data1 != 'apple'
# Out:
# False

# %%
data1 < data2
# Out:
# True

# %%
data2 == 'baNana'
# Out:
# False

# %%
# 나이 >= 30
# 성별 == '여자'
# 결혼유무 == True
# 1달평균소비금액 >= 300000
# 자녀수 >= 2
# [나이 >= 30] and [성별 == '여자'] and [결혼유무 == Tru] and [1달평균소비금액 >= 300000] and [자녀수 >= 2]

# %%
temp_ok = True
pressure_ok = True

# %%
is_running = True

# %%
not is_running
# Out:
# False

# %%
temp = 185
pressure = 1.2
is_maintenance = False

# %%
# 온도와 압력이 정상이고,정비 중이 아닐 때 가동
# 온도 정상은 150 이상이고, 200 이하일 때 정상
# 압력 정상은 1.0 이상이고, 1.5 이하일 때 정상

# %%
temp >= 150 and temp <= 200 and pressure >= 1.0 and pressure <= 1.5 and not is_maintenance
# Out:
# True

# %%
150 <= temp <= 200 and 1.0 <= pressure <= 1.5 and not is_maintenance
# Out:
# True
