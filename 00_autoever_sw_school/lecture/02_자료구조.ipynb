# %%
[]
# Out:
# []

# %%
word = 'temp'

# %%
word[1]
# Out:
# 'e'

# %%
temps = [185.5, 186.2, 184.8, 185.0, 186.1]

# %%
list()
# Out:
# []

# %%
temps[0]
# Out:
# 185.5

# %%
temps[2]
# Out:
# 184.8

# %%
temps[-1]
# Out:
# 186.1

# %%
temps[2] = 187

# %%
temps
# Out:
# [185.5, 186.2, 187, 185.0, 186.1]

# %%
temps[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 temps[6]
#
# IndexError: list index out of range

# %%
temps[1:3 + 1]
# Out:
# [186.2, 187, 185.0]

# %%
list1 = [1, 2, 3]

# %%
list1*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
machine = ['CNC', 'Press', 'Lathe']

# %%
'CNC' in machine
# Out:
# True

# %%
'CNC' not in machine
# Out:
# False

# %%
len(machine)
# Out:
# 3

# %%
machine = ['CNC', 'Press']

# %%
machine.append('Lathe')

# %%
machine
# Out:
# ['CNC', 'Press', 'Lathe']

# %%
machine.append('Drill')

# %%
machine
# Out:
# ['CNC', 'Press', 'Lathe', 'Drill']

# %%
machine.insert(2, 'Mill')

# %%
machine
# Out:
# ['CNC', 'Press', 'Mill', 'Lathe', 'Drill']

# %%
machine.insert(0, 'Robot')

# %%
machine
# Out:
# ['Robot', 'CNC', 'Press', 'Mill', 'Lathe', 'Drill']

# %%
# 여러 데이터 추가

# %%
machine = ['CNC', 'Press']

# %%
new_machine = ['Lathe', 'Drill']

# %%
machine.extend(new_machine)

# %%
machine
# Out:
# ['CNC', 'Press', 'Lathe', 'Drill']

# %%
machine.remove('Press')

# %%
machine
# Out:
# ['CNC', 'Lathe', 'Drill']

# %%
machine.remove('Robot')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 machine.remove('Robot')
#
# ValueError: list.remove(x): x not in list

# %%
machine = ['CNC', 'Press', 'Lathe', 'Drill']

# %%
machine.pop()
# Out:
# 'Drill'

# %%
machine
# Out:
# ['CNC', 'Press', 'Lathe']

# %%
machine.pop(1)
# Out:
# 'Press'

# %%
machine
# Out:
# ['CNC', 'Lathe']

# %%
del machine[0]

# %%
machine
# Out:
# ['Lathe']

# %%
machine.clear()

# %%
machine
# Out:
# []

# %%
machine = ['CNC', 'Press', 'Lathe', 'Drill']

# %%
# 인덱스 찾기

# %%
machine.index('CNC')
# Out:
# 0

# %%
len(machine)
# Out:
# 4

# %%
machine.append('CNC')

# %%
machine
# Out:
# ['CNC', 'Press', 'Lathe', 'Drill', 'CNC']

# %%
machine.count('CNC')
# Out:
# 2

# %%
numbers = [3, 1, 4, 1, 5, 9, 2, 6]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 1, 2, 3, 4, 5, 6, 9]

# %%
numbers.sort(reverse=True)

# %%
numbers
# Out:
# [9, 6, 5, 4, 3, 2, 1, 1]

# %%
sorted(numbers, reverse=False)
# Out:
# [1, 1, 2, 3, 4, 5, 6, 9]

# %%
numbers
# Out:
# [9, 6, 5, 4, 3, 2, 1, 1]

# %%
numbers[::-1]
# Out:
# [1, 1, 2, 3, 4, 5, 6, 9]

# %%
numbers.reverse()

# %%
numbers
# Out:
# [1, 1, 2, 3, 4, 5, 6, 9]

# %%
max(numbers)
# Out:
# 9

# %%
min(numbers)
# Out:
# 1

# %%
sum(numbers)
# Out:
# 31

# %%
sum(numbers)/len(numbers)
# Out:
# 3.875

# %%
any(numbers)
# Out:
# True

# %%
all(numbers)
# Out:
# True

# %%
numbers = [False, False, True]

# %%
any(numbers)
# Out:
# True

# %%
all(numbers)
# Out:
# False

# %%
matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[1]
# Out:
# [4, 5, 6]

# %%
matrix[1][2]
# Out:
# 6

# %%
# 튜플

# %%
# 리스트랑 똑같이 여러개의 데이터를 담되, 한 번 담으면 끝

# %%
location = (37.123, 127.221)

# %%
location
# Out:
# (37.123, 127.221)

# %%
location[0]
# Out:
# 37.123

# %%
location[-110]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 location[-110]
#
# IndexError: tuple index out of range

# %%
(10000, 100, 7)
# Out:
# (10000, 100, 7)

# %%
(7)
# Out:
# 7

# %%
(7,)
# Out:
# (7,)

# %%
numbers = (1, 2, 3, 4, 5)

# %%
a, b, c, d, e = numbers

# %%
# 딕셔너리: key, value의 쌍으로 데이터를 저장

# %%
{}
# Out:
# {}

# %%
machine = {'id': 'MC001', 'type': 'CNC', 'temperature': 185.5, 'is_running': True}

# %%
machine['id']
# Out:
# 'MC001'

# %%
machine.get('id')
# Out:
# 'MC001'

# %%
machine['color']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 machine['color']
#
# KeyError: 'color'

# %%
machine.get('color')

# %%
machine
# Out:
# {'id': 'MC001', 'type': 'CNC', 'temperature': 185.5, 'is_running': True}

# %%
machine['temperature'] = 190

# %%
machine
# Out:
# {'id': 'MC001', 'type': 'CNC', 'temperature': 190, 'is_running': True}

# %%
machine['color'] = 'red'

# %%
machine
# Out:
# {'id': 'MC001',
#  'type': 'CNC',
#  'temperature': 190,
#  'is_running': True,
#  'color': 'red'}

# %%
del machine['color']

# %%
machine
# Out:
# {'id': 'MC001', 'type': 'CNC', 'temperature': 190, 'is_running': True}

# %%
eventA = {1, 5, 8}

# %%
eventB = {5, 100}

# %%
eventB.add(421)

# %%
eventB
# Out:
# {5, 100, 421}

# %%
eventA & eventB
# Out:
# {5}

# %%
eventA - eventB
# Out:
# {1, 8}

# %%
eventA | eventB
# Out:
# {1, 5, 8, 100, 421}

# %%
eventB - eventA
# Out:
# {100, 421}

# %%
page_view = []

# %%
page_view.append(31)

# %%
page_view.append(100)

# %%
page_view.append(31)

# %%
page_view.append(50)

# %%
page_view
# Out:
# [31, 100, 31, 50]
