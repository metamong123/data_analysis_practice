# %%
import pandas as pd

# %%
df2 = pd.read_csv('./data/02_product.csv')

# %%
df2
# Out:
#   product_code product_name   specification unit  standard_cycle_time  \
# 0     BUMPER-A           범퍼  1200x300x150mm   EA                 75.0
# 1       DOOR-B         도어패널    800x600x50mm   EA                 65.0
# 2       DASH-C         대시보드   1000x400x80mm   EA                 85.0
#
#    target_quality_rate  upper_spec_limit  lower_spec_limit  \
# 0                 98.5             305.0             295.0
# 1                 99.0             605.0             595.0
# 2                 98.0             405.0             395.0
#
#             created_at           updated_at
# 0  2024-01-01 00:00:00  2024-01-01 00:00:00
# 1  2024-01-01 00:00:00  2024-01-01 00:00:00
# 2  2024-01-01 00:00:00  2024-01-01 00:00:00

# %%
df2.tail()
# Out:
#   product_code product_name   specification unit  standard_cycle_time  \
# 0     BUMPER-A           범퍼  1200x300x150mm   EA                 75.0
# 1       DOOR-B         도어패널    800x600x50mm   EA                 65.0
# 2       DASH-C         대시보드   1000x400x80mm   EA                 85.0
#
#    target_quality_rate  upper_spec_limit  lower_spec_limit  \
# 0                 98.5             305.0             295.0
# 1                 99.0             605.0             595.0
# 2                 98.0             405.0             395.0
#
#             created_at           updated_at
# 0  2024-01-01 00:00:00  2024-01-01 00:00:00
# 1  2024-01-01 00:00:00  2024-01-01 00:00:00
# 2  2024-01-01 00:00:00  2024-01-01 00:00:00

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_code         3 non-null      object
#  1   product_name         3 non-null      object
#  2   specification        3 non-null      object
#  3   unit                 3 non-null      object
#  4   standard_cycle_time  3 non-null      float64
#  5   target_quality_rate  3 non-null      float64
#  6   upper_spec_limit     3 non-null      float64
#  7   lower_spec_limit     3 non-null      float64
#  8   created_at           3 non-null      object
#  9   updated_at           3 non-null      object
# dtypes: float64(4), object(6)
# memory usage: 368.0+ bytes

# %%
df1 = pd.read_csv('./data/01_equipment.csv')

# %%
df1 = df1.set_index('equipment_id')

# %%
df1
# Out:
#              equipment_name equipment_type location  rated_capacity  \
# equipment_id
# INJ-001             사출기 1호기            사출기   A동 1라인           150.0
# INJ-002             사출기 2호기            사출기   A동 1라인           150.0
# PRESS-001           프레스 1호기            프레스   A동 2라인           200.0
# PRESS-002           프레스 2호기            프레스   A동 2라인           200.0
# ASM-001            조립라인 1호기           조립라인   B동 1라인           100.0
#
#              installation_date  status           created_at  \
# equipment_id
# INJ-001             2020-03-15  ACTIVE  2024-01-01 00:00:00
# INJ-002             2021-06-20  ACTIVE  2024-01-01 00:00:00
# PRESS-001           2019-05-10  ACTIVE  2024-01-01 00:00:00
# PRESS-002           2022-08-25  ACTIVE  2024-01-01 00:00:00
# ASM-001             2020-11-30  ACTIVE  2024-01-01 00:00:00
#
#                        updated_at
# equipment_id
# INJ-001       2024-01-01 00:00:00
# INJ-002       2024-01-01 00:00:00
# PRESS-001     2024-01-01 00:00:00
# ...

# %%
df5 = pd.read_csv('./data/05_production.csv')

# %%
df5
# Out:
#       production_id equipment_id product_code production_date  \
# 0                 1      INJ-001     BUMPER-A      2024-01-01
# 1                 2      INJ-001     BUMPER-A      2024-01-01
# 2                 3      INJ-002     BUMPER-A      2024-01-01
# 3                 4      INJ-002       DASH-C      2024-01-01
# 4                 5      INJ-002       DOOR-B      2024-01-01
# ...             ...          ...          ...             ...
# 1867           1868    PRESS-002     BUMPER-A      2024-03-31
# 1868           1869    PRESS-002       DASH-C      2024-03-31
# 1869           1870    PRESS-002     BUMPER-A      2024-03-31
# 1870           1871      ASM-001     BUMPER-A      2024-03-31
# 1871           1872      ASM-001       DOOR-B      2024-03-31
#
#                start_time             end_time  target_quantity  \
# 0     2024-01-01 08:14:00  2024-01-01 09:53:32               97
# 1     2024-01-01 21:02:00  2024-01-01 22:33:43               83
# ...

# %%
df5.head()
# Out:
#    production_id equipment_id product_code production_date  \
# 0              1      INJ-001     BUMPER-A      2024-01-01
# 1              2      INJ-001     BUMPER-A      2024-01-01
# 2              3      INJ-002     BUMPER-A      2024-01-01
# 3              4      INJ-002       DASH-C      2024-01-01
# 4              5      INJ-002       DOOR-B      2024-01-01
#
#             start_time             end_time  target_quantity  actual_quantity  \
# 0  2024-01-01 08:14:00  2024-01-01 09:53:32               97               81
# 1  2024-01-01 21:02:00  2024-01-01 22:33:43               83               78
# 2  2024-01-01 10:12:00  2024-01-01 13:16:28              149              135
# 3  2024-01-01 12:48:00  2024-01-01 15:16:31              100               92
# 4  2024-01-01 20:48:00  2024-01-01 23:12:13              123              129
#
#    good_quantity  defect_quantity  cycle_time   work_order_no  \
# 0             77                4       73.73  WO202401019935
# ...

# %%
df5.shape # (row: 데이터 개수, column: 특징 개수)
# Out:
# (1872, 17)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1872 entries, 0 to 1871
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   production_id    1872 non-null   int64
#  1   equipment_id     1872 non-null   object
#  2   product_code     1872 non-null   object
#  3   production_date  1872 non-null   object
#  4   start_time       1872 non-null   object
#  5   end_time         1872 non-null   object
#  6   target_quantity  1872 non-null   int64
#  7   actual_quantity  1872 non-null   int64
#  8   good_quantity    1872 non-null   int64
#  9   defect_quantity  1872 non-null   int64
#  10  cycle_time       1872 non-null   float64
#  11  work_order_no    1872 non-null   object
#  12  lot_no           1872 non-null   object
#  13  operator_id      1872 non-null   object
#  14  shift            1872 non-null   object
#  15  created_at       1872 non-null   object
#  16  updated_at       1872 non-null   object
# ...

# %%
df5 = pd.read_csv('./data/05_production.csv', parse_dates=['production_date', 'start_time', 'end_time', 'created_at', 'updated_at'])

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1872 entries, 0 to 1871
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   production_id    1872 non-null   int64
#  1   equipment_id     1872 non-null   object
#  2   product_code     1872 non-null   object
#  3   production_date  1872 non-null   datetime64[ns]
#  4   start_time       1872 non-null   datetime64[ns]
#  5   end_time         1872 non-null   datetime64[ns]
#  6   target_quantity  1872 non-null   int64
#  7   actual_quantity  1872 non-null   int64
#  8   good_quantity    1872 non-null   int64
#  9   defect_quantity  1872 non-null   int64
#  10  cycle_time       1872 non-null   float64
#  11  work_order_no    1872 non-null   object
#  12  lot_no           1872 non-null   object
#  13  operator_id      1872 non-null   object
#  14  shift            1872 non-null   object
#  15  created_at       1872 non-null   datetime64[ns]
# ...

# %%
# 필요한 컬럼만 불러오기

# %%
pd.read_csv('./data/05_production.csv',
            usecols=['production_id', 'equipment_id', 'product_code', 'production_date',
                     'actual_quantity', 'good_quantity', 'defect_quantity'])
# Out:
#       production_id equipment_id product_code production_date  \
# 0                 1      INJ-001     BUMPER-A      2024-01-01
# 1                 2      INJ-001     BUMPER-A      2024-01-01
# 2                 3      INJ-002     BUMPER-A      2024-01-01
# 3                 4      INJ-002       DASH-C      2024-01-01
# 4                 5      INJ-002       DOOR-B      2024-01-01
# ...             ...          ...          ...             ...
# 1867           1868    PRESS-002     BUMPER-A      2024-03-31
# 1868           1869    PRESS-002       DASH-C      2024-03-31
# 1869           1870    PRESS-002     BUMPER-A      2024-03-31
# 1870           1871      ASM-001     BUMPER-A      2024-03-31
# 1871           1872      ASM-001       DOOR-B      2024-03-31
#
#       actual_quantity  good_quantity  defect_quantity
# 0                  81             77                4
# 1                  78             72                6
# 2                 135            132                3
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1872 entries, 0 to 1871
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   production_id    1872 non-null   int64
#  1   equipment_id     1872 non-null   object
#  2   product_code     1872 non-null   object
#  3   production_date  1872 non-null   datetime64[ns]
#  4   start_time       1872 non-null   datetime64[ns]
#  5   end_time         1872 non-null   datetime64[ns]
#  6   target_quantity  1872 non-null   int64
#  7   actual_quantity  1872 non-null   int64
#  8   good_quantity    1872 non-null   int64
#  9   defect_quantity  1872 non-null   int64
#  10  cycle_time       1872 non-null   float64
#  11  work_order_no    1872 non-null   object
#  12  lot_no           1872 non-null   object
#  13  operator_id      1872 non-null   object
#  14  shift            1872 non-null   object
#  15  created_at       1872 non-null   datetime64[ns]
# ...

# %%
df5.head()
# Out:
#    production_id equipment_id product_code production_date  \
# 0              1      INJ-001     BUMPER-A      2024-01-01
# 1              2      INJ-001     BUMPER-A      2024-01-01
# 2              3      INJ-002     BUMPER-A      2024-01-01
# 3              4      INJ-002       DASH-C      2024-01-01
# 4              5      INJ-002       DOOR-B      2024-01-01
#
#            start_time            end_time  target_quantity  actual_quantity  \
# 0 2024-01-01 08:14:00 2024-01-01 09:53:32               97               81
# 1 2024-01-01 21:02:00 2024-01-01 22:33:43               83               78
# 2 2024-01-01 10:12:00 2024-01-01 13:16:28              149              135
# 3 2024-01-01 12:48:00 2024-01-01 15:16:31              100               92
# 4 2024-01-01 20:48:00 2024-01-01 23:12:13              123              129
#
#    good_quantity  defect_quantity  cycle_time   work_order_no  \
# 0             77                4       73.73  WO202401019935
# ...

# %%
df5_2 = pd.read_csv('./data/05_production.csv',
                    dtype={'equipment_id':'category', 'product_code':'category'})

# %%
df5_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1872 entries, 0 to 1871
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   production_id    1872 non-null   int64
#  1   equipment_id     1872 non-null   category
#  2   product_code     1872 non-null   category
#  3   production_date  1872 non-null   object
#  4   start_time       1872 non-null   object
#  5   end_time         1872 non-null   object
#  6   target_quantity  1872 non-null   int64
#  7   actual_quantity  1872 non-null   int64
#  8   good_quantity    1872 non-null   int64
#  9   defect_quantity  1872 non-null   int64
#  10  cycle_time       1872 non-null   float64
#  11  work_order_no    1872 non-null   object
#  12  lot_no           1872 non-null   object
#  13  operator_id      1872 non-null   object
#  14  shift            1872 non-null   object
#  15  created_at       1872 non-null   object
# ...
