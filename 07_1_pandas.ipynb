# %%
import pandas as pd
#1차원과 2차원 데이터를 다루기 쉽게 만든 라이브러리

# %%
# 1차원 데이터: Series
# index | values
production = pd.Series([450, 480, 465, 490, 470])

# %%
production.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
production.values
# Out:
# array([450, 480, 465, 490, 470])

# %%
production
# Out:
# 0    450
# 1    480
# 2    465
# 3    490
# 4    470
# dtype: int64

# %%
production = pd.Series(data=[450, 480, 465, 490, 470], index=['월요일', '화요일', '수요일', '목요일', '금요일'])

# %%
production.values
# Out:
# array([450, 480, 465, 490, 470])

# %%
production.index
# Out:
# Index(['월요일', '화요일', '수요일', '목요일', '금요일'], dtype='object')

# %%
production.index.tolist()
# Out:
# ['월요일', '화요일', '수요일', '목요일', '금요일']

# %%
production.size
# Out:
# 5

# %%
production.ndim
# Out:
# 1

# %%
production.shape
# Out:
# (5,)

# %%
production
# Out:
# 월요일    450
# 화요일    480
# 수요일    465
# 목요일    490
# 금요일    470
# dtype: int64

# %%
production[['화요일', '수요일']]
# Out:
# 화요일    480
# 수요일    465
# dtype: int64

# %%
production[production >= 480]
# Out:
# 화요일    480
# 목요일    490
# dtype: int64

# %%
production
# Out:
# 월요일    450
# 화요일    480
# 수요일    465
# 목요일    490
# 금요일    470
# dtype: int64

# %%
production = production + 10

# %%
production
# Out:
# 월요일    460
# 화요일    490
# 수요일    475
# 목요일    500
# 금요일    480
# dtype: int64

# %%
production['화요일'] -= 30

# %%
production[['월요일', '목요일', '금요일']] += 20

# %%
production
# Out:
# 월요일    480
# 화요일    460
# 수요일    475
# 목요일    520
# 금요일    500
# dtype: int64

# %%
equipment_data = {
    'equipment_id': ['INJ-001', 'INJ-002', 'PRESS-001', 'PRESS-002', 'ASM-001'],
    'equipment_name': ['사출기 1호기', '사출기 2호기', '프레스 1호기', '프레스 2호기', '조립라인 1호기'],
    'equipment_type': ['사출기', '사출기', '프레스', '프레스', '조립라인'],
    'location': ['A동 1라인', 'A동 1라인', 'A동 2라인', 'A동 2라인', 'B동 1라인'],
    'rated_capacity': [150, 150, 200, 200, 100],
    'status': ['ACTIVE', 'ACTIVE', 'ACTIVE', 'ACTIVE', 'ACTIVE']
}

# %%
# 2차원 데이터: DataFrame
# index | columns
#       | values
df = pd.DataFrame(data=equipment_data)

# %%
df
# Out:
#   equipment_id equipment_name equipment_type location  rated_capacity  status
# 0      INJ-001        사출기 1호기            사출기   A동 1라인             150  ACTIVE
# 1      INJ-002        사출기 2호기            사출기   A동 1라인             150  ACTIVE
# 2    PRESS-001        프레스 1호기            프레스   A동 2라인             200  ACTIVE
# 3    PRESS-002        프레스 2호기            프레스   A동 2라인             200  ACTIVE
# 4      ASM-001       조립라인 1호기           조립라인   B동 1라인             100  ACTIVE

# %%
df.set_index('equipment_id', inplace=True)

# %%
df
# Out:
#              equipment_name equipment_type location  rated_capacity  status
# equipment_id
# INJ-001             사출기 1호기            사출기   A동 1라인             150  ACTIVE
# INJ-002             사출기 2호기            사출기   A동 1라인             150  ACTIVE
# PRESS-001           프레스 1호기            프레스   A동 2라인             200  ACTIVE
# PRESS-002           프레스 2호기            프레스   A동 2라인             200  ACTIVE
# ASM-001            조립라인 1호기           조립라인   B동 1라인             100  ACTIVE

# %%
df.index
# Out:
# Index(['INJ-001', 'INJ-002', 'PRESS-001', 'PRESS-002', 'ASM-001'], dtype='object', name='equipment_id')

# %%
df.columns
# Out:
# Index(['equipment_name', 'equipment_type', 'location', 'rated_capacity',
#        'status'],
#       dtype='object')

# %%
df.describe(include='all')
# Out:
#        equipment_name equipment_type location  rated_capacity  status
# count               5              5        5        5.000000       5
# unique              5              3        3             NaN       1
# top           사출기 1호기            사출기   A동 1라인             NaN  ACTIVE
# freq                1              2        2             NaN       5
# mean              NaN            NaN      NaN      160.000000     NaN
# std               NaN            NaN      NaN       41.833001     NaN
# min               NaN            NaN      NaN      100.000000     NaN
# 25%               NaN            NaN      NaN      150.000000     NaN
# 50%               NaN            NaN      NaN      150.000000     NaN
# 75%               NaN            NaN      NaN      200.000000     NaN
# max               NaN            NaN      NaN      200.000000     NaN

# %%
# 데이터프레임에서 데이터 가져오는 방법
# 1. 컬럼 데이터
# 2. .loc[ , ]로 가져오기
# 3. .iloc[ , ]로 가져오기

# %%
df
# Out:
#              equipment_name equipment_type location  rated_capacity  status
# equipment_id
# INJ-001             사출기 1호기            사출기   A동 1라인             150  ACTIVE
# INJ-002             사출기 2호기            사출기   A동 1라인             150  ACTIVE
# PRESS-001           프레스 1호기            프레스   A동 2라인             200  ACTIVE
# PRESS-002           프레스 2호기            프레스   A동 2라인             200  ACTIVE
# ASM-001            조립라인 1호기           조립라인   B동 1라인             100  ACTIVE

# %%
df['equipment_name']
# Out:
# equipment_id
# INJ-001       사출기 1호기
# INJ-002       사출기 2호기
# PRESS-001     프레스 1호기
# PRESS-002     프레스 2호기
# ASM-001      조립라인 1호기
# Name: equipment_name, dtype: object

# %%
df[['equipment_type', 'location', 'rated_capacity']]
# Out:
#              equipment_type location  rated_capacity
# equipment_id
# INJ-001                 사출기   A동 1라인             150
# INJ-002                 사출기   A동 1라인             150
# PRESS-001               프레스   A동 2라인             200
# PRESS-002               프레스   A동 2라인             200
# ASM-001                조립라인   B동 1라인             100

# %%
df['equipment_type':'rated_capacity']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rapa\miniconda3\envs\smart\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'equipment_type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 1
# ...

# %%
df.loc['INJ-002', :]
# Out:
# equipment_name    사출기 2호기
# equipment_type        사출기
# location           A동 1라인
# rated_capacity        150
# status             ACTIVE
# Name: INJ-002, dtype: object

# %%
df.loc[['INJ-002', 'PRESS-001'], :]
# Out:
#              equipment_name equipment_type location  rated_capacity  status
# equipment_id
# INJ-002             사출기 2호기            사출기   A동 1라인             150  ACTIVE
# PRESS-001           프레스 1호기            프레스   A동 2라인             200  ACTIVE

# %%
df.loc['INJ-002':'PRESS-001', :]
# Out:
#              equipment_name equipment_type location  rated_capacity  status
# equipment_id
# INJ-002             사출기 2호기            사출기   A동 1라인             150  ACTIVE
# PRESS-001           프레스 1호기            프레스   A동 2라인             200  ACTIVE

# %%
df.loc[:, 'equipment_type':'rated_capacity']
# Out:
#              equipment_type location  rated_capacity
# equipment_id
# INJ-001                 사출기   A동 1라인             150
# INJ-002                 사출기   A동 1라인             150
# PRESS-001               프레스   A동 2라인             200
# PRESS-002               프레스   A동 2라인             200
# ASM-001                조립라인   B동 1라인             100

# %%
df.loc['INJ-002':'PRESS-002', 'equipment_type':'rated_capacity']
# Out:
#              equipment_type location  rated_capacity
# equipment_id
# INJ-002                 사출기   A동 1라인             150
# PRESS-001               프레스   A동 2라인             200
# PRESS-002               프레스   A동 2라인             200

# %%
df
# Out:
#              equipment_name equipment_type location  rated_capacity  status
# equipment_id
# INJ-001             사출기 1호기            사출기   A동 1라인             150  ACTIVE
# INJ-002             사출기 2호기            사출기   A동 1라인             150  ACTIVE
# PRESS-001           프레스 1호기            프레스   A동 2라인             200  ACTIVE
# PRESS-002           프레스 2호기            프레스   A동 2라인             200  ACTIVE
# ASM-001            조립라인 1호기           조립라인   B동 1라인             100  ACTIVE

# %%
df.iloc[1:4, 1:4]
# Out:
#              equipment_type location  rated_capacity
# equipment_id
# INJ-002                 사출기   A동 1라인             150
# PRESS-001               프레스   A동 2라인             200
# PRESS-002               프레스   A동 2라인             200
